# %%
import pandas as pd

# %%
path = './nothing/nothing_1_71_2/concat_csv.txt'
df = pd.read_csv(path, header=None)

# %%
df
# Out:
#           0           1           2           3           4           5     \
# 0    86.302720   80.398637   74.662539   69.094425   63.694296   58.462151
# 1  -130.196508 -127.092407 -123.961533 -120.803885 -117.619463 -114.408267
# 2    24.665606   26.476897   28.179409   29.773140   31.258092   32.634264
# 3  -162.703518 -150.805524 -139.248262 -128.031732 -117.155935 -106.620871
# 4   104.742331   98.044765   91.552759   85.266313   79.185426   73.310098
# ..         ...         ...         ...         ...         ...         ...
# 95  -64.550711  -59.820475  -55.237428  -50.801569  -46.512898  -42.371415
# 96  -51.660396  -47.953623  -44.353883  -40.861175  -37.475499  -34.196856
# 97   44.168982   43.962546   43.709727   43.410526   43.064942   42.672975
# 98   61.064023   60.707563   60.291428   59.815617   59.280131   58.684969
# 99  -37.102547  -35.358948  -33.647868  -31.969305  -30.323260  -28.709733
#
# ...

# %%
df.loc[:,1500] = ['nothing']*100

# %%
df
# Out:
#           0           1           2           3           4           5     \
# 0    86.302720   80.398637   74.662539   69.094425   63.694296   58.462151
# 1  -130.196508 -127.092407 -123.961533 -120.803885 -117.619463 -114.408267
# 2    24.665606   26.476897   28.179409   29.773140   31.258092   32.634264
# 3  -162.703518 -150.805524 -139.248262 -128.031732 -117.155935 -106.620871
# 4   104.742331   98.044765   91.552759   85.266313   79.185426   73.310098
# ..         ...         ...         ...         ...         ...         ...
# 95  -64.550711  -59.820475  -55.237428  -50.801569  -46.512898  -42.371415
# 96  -51.660396  -47.953623  -44.353883  -40.861175  -37.475499  -34.196856
# 97   44.168982   43.962546   43.709727   43.410526   43.064942   42.672975
# 98   61.064023   60.707563   60.291428   59.815617   59.280131   58.684969
# 99  -37.102547  -35.358948  -33.647868  -31.969305  -30.323260  -28.709733
#
# ...

# %%
df.to_csv('./nothing/nothing_1_71_2/with_tag.csv', header=None, index=None)
